# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
ctp = pd.read_csv('plpop_sample_v3.csv')
ctp
# Out:
#       host_name        koi spec_type          RA        DEC  distance  \
# 0   Kepler-1008  K01904.01       NaN  296.547525  44.941933    299.00
# 1   Kepler-1027  K01961.01       NaN  287.571185  42.813923    291.00
# 2    Kepler-104  K00111.03       NaN  287.604612  42.166779    405.42
# 3   Kepler-1063  K02032.01       NaN  290.526750  38.142973    365.00
# 4    Kepler-108  K00119.01       NaN  294.559169  46.062325    729.00
# 5   Kepler-1086  K02078.01       NaN  295.251155  45.842972    464.00
# 6   Kepler-1130  K02169.01       NaN  285.207485  45.384350    234.00
# 7   Kepler-1150  K02225.01       NaN  296.724492  49.532715    373.00
# 8    Kepler-132  K00284.01       NaN  283.235810  41.343037    303.00
# 9   Kepler-1341  K02762.01       NaN  280.511769  44.159351    466.00
# 10    Kepler-14  K00098.01       NaN  287.708814  47.333050    980.00
# 11  Kepler-1480  K03365.01       NaN  291.999771  49.301811    540.00
# ...

# %%
plt.scatter(result.Teff,result.K_mag)

# %%
ctp.Teff.hist()

# %%
result = pd.read_csv('plpop_results_1.csv')

# %%
result.plpop_teff_0.hist(bins=20)
